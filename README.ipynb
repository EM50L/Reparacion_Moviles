# %% [markdown]
# ## Enlaces y Recursos Reparacion de Moviles.
#
# ![Logos.jpg](attachment:22cafaaa-7a67-4951-aec0-4ddf942b1217.jpg)
#
# https://www.institutoeuropa.com/

# %% [markdown]
# ---
# # Reparabilidad
#
# Nuevo Índice de Reparabilidad.
# https://www.remle.com/es/blog/nuevo-indice-de-reparabilidad.html
#
# Derecho a reparar: qué establece la nueva normativa.
# https://www.eldiario.es/consumoclaro/derecho-reparar-establece-nueva-normativa_1_7325250.html

# %% [markdown]
# ## ifixit (Pagina web con recursos para reparar moviles)
#
# Calificación de reparabilidad de los smartphones.
# https://es.ifixit.com/reparabilidad/calificacion-de-smartphones
#
# Guias de Reparacion.
# https://es.ifixit.com/Device/Phone

# %% [markdown]
# ---
#
# # Conexion al Ordenador
#
# * Vysor
# https://app.vysor.io/#/
# (Recuerda mirar video de como se activan las opciones de desarollador y el adb)
#
#
# * ScrCpy (Mas complicado pero mas potente )
# Tutorial:  https://github.com/Genymobile/scrcpy
# Descargas: https://github.com/Genymobile/scrcpy/releases (Descargar scrcpy-win64-v2.7.zip)

# %% [markdown]
# ---
#
# # Diagnostico Conexion USB
#
# * Usb Tester
#   https://www.google.es/search?q=usb+tester
#
# * Usb Log View
#   https://www.nirsoft.net/utils/usb_log_view.html

# %% [markdown]
# ---
#
# # Programa para la gestion de un taller de reparaciones
#
# * CP Reparaciones (Utilidad para Talleres)
# https://www.cpimario.com/index5.html

# %% [markdown]
# ---
#
# # Programacion de un Micro (Via WEB)
#
# * https://circuitpython.org/downloads
# Escoger dispositivo
#
# * ESP web Flasher https://adafruit.github.io/Adafruit_WebSerial_ESPTool/
#
# * Google Labs Serial terminal  https://googlechromelabs.github.io/serial-terminal/

# %% [markdown]
# ---
#
# # adb fastboot: formateo y restauracion a estado Fabrica
# <div class="alert alert-block alert-danger">
# <b> Importante:</b> Acuerdate de borrar antes las todas las cuentas del Movil.
# </div>
#
#
# ### Método 1: Desde los Ajustes del Sistema
# * Busqueda con IA: como Restaurar un movil a Fabrica
#   https://www.perplexity.ai/search/como-restaurar-un-movil-a-fabr-ePITdFX7QaOpzhgIEGe9Sw
#
# ### Método 2: Usando el Modo Recovery
# 1) Instala adb (scrcpy y vysor vienen con un adb interno)
#    Ve a la carpeta donde estan scrcpy o vysor y en el cuadro de busquedda por adb.
#
# 2) Busqueda con IA: comandos adb utiles para reparar un movil
#    https://www.perplexity.ai/search/una-guia-de-recursos-de-repara-7Ji7_OSuQdats0l_ZltQuw
#    Truco: sigue conversando con la IA preguntandole algo de lo que estaa en el articulo.
#
# ### Mas recursos WEB:
#    https://wiki.lineageos.org/adb_fastboot_guide
#    https://source.android.com/docs/setup/test/running?hl=es-419

# %% [markdown]
# ---
#
# ## IA (Peguntale lo que sea)
#
# https://www.perplexity.ai

# %% [markdown]
# ---
#
# ## Virus y malware
#
# https://www.virustotal.com/gui/home/upload
#
#
# https://www.incibe.es/ciudadania/herramientas/conan-mobile

# %% [markdown]
# ---
#
# ## Laboratorio Seguro (virtualbox y emuladores de Android)
#
# Virtualbox
# https://www.virtualbox.org
#
# VMware
# https://softwareupdate.vmware.com/cds/vmw-desktop/ws/
#
# Android X86 (un android en tu pc antiguo)
# https://www.android-x86.org
#
# LineageOS
# https://www.osboxes.org/lineageos-14-1-r5-cynagenmod-images-available-for-virtualbox-and-vmware/

# %% [markdown]
# ---
#
# ## Modo Recovery
# ## Reinstalar ROM desde cero / cambiar version de Android
#
# LineageOS (Alternativa libre a Android.).
# https://wiki.lineageos.org/devices/
# En la web Explica como se reiniciar en modo recovery varios dispositivos.
#
# /e/OS is a complete mobile ecosystem (alternativa libre a Google).
# https://doc.e.foundation/devices
# En la web Explica como se reiniciar en modo recovery varios dispositivos.
#
# TeamWin - TWRP (Copias de Seguridad)
# https://twrp.me/Devices/
# https://unofficialtwrp.com/devices/

# %% [markdown]
# ---
#
# # Varios:
#
# -Flasear Google Pixel (desde Web)
# https://flash.android.com/
#
#
# -Debian en Android Tvs
# https://github.com/ophub/amlogic-s9xxx-armbian?tab=readme-ov-file
#
#
# -Project Scriptbd Crear Roms
# https://xdaforums.com/t/guide-tool-linux-projekt-scribt-v2-2-1-build-a-rom-newbie-friendly.3503018/
#
#
# https://infofuge.cm/root-android-smartphone/
#
# https://droidwin.com/fix-writing-system-failed-remote-partition-not-found/
